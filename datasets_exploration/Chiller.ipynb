# %%
base_folder = r"C:\Users\tre_i\LBNL FDD Datasets"

# %%
dataset_folder = 'LBNL_FDD_Data_Sets_Chiller_Plant_all_3'

# %%
import os
from os.path import join
import pandas as pd

# %%
folder = join(base_folder, dataset_folder)
os.listdir(folder)
# Out:
# ['ChillerPlant.csv',
#  'ChillerPlant_bypass_leakage_025.csv',
#  'ChillerPlant_bypass_leakage_050.csv',
#  'ChillerPlant_bypass_leakage_075.csv',
#  'ChillerPlant_bypass_stuck_050.csv',
#  'ChillerPlant_bypass_stuck_075.csv',
#  'ChillerPlant_chiller_bias_-1.csv',
#  'ChillerPlant_chiller_bias_-2.csv',
#  'ChillerPlant_chiller_bias_1.csv',
#  'ChillerPlant_chiller_bias_2.csv',
#  'ChillerPlant_chiller_fouling_065.csv',
#  'ChillerPlant_chiller_fouling_095.csv',
#  'ChillerPlant_coolingtower_bias_-1.csv',
#  'ChillerPlant_coolingtower_bias_-2.csv',
#  'ChillerPlant_coolingtower_bias_1.csv',
#  'ChillerPlant_coolingtower_bias_2.csv',
#  'ChillerPlant_coolingtower_fouling_065.csv',
#  'ChillerPlant_coolingtower_fouling_080.csv',
#  'ChillerPlant_coolingtower_fouling_095.csv',
#  'ChillerPlant_coolingtower_PI.csv',
#  'ChillerPlant_secondary_chilled_water_pressure_bias_-010.csv',
#  'ChillerPlant_secondary_chilled_water_pressure_bias_-020.csv',
#  'ChillerPlant_secondary_chilled_water_pressure_bias_010.csv',
#  'ChillerPlant_secondary_chilled_water_pressure_bias_020.csv',
#  'LBNL_FDD_Data_Sets_Chiller_Plant.pdf',
#  'LBNL_FDD_Data_Sets_chiller_plant.ttl',
#  '__MACOSX']

# %%
len([el for el in os.listdir(folder) if 'csv' in el])
# Out:
# 24

# %%
data_normal = pd.read_csv(join(folder, 'ChillerPlant.csv'))
data_normal.head()
# Out:
#               Datetime  CDWL_CW_FLOW  CDWL_PM_POW_1  CDWL_PM_POW_2  \
# 0  2018-01-01 01:00:00    321.582963      46.084146   0.000000e+00
# 1  2018-01-01 01:01:00    321.582963      46.084146   0.000000e+00
# 2  2018-01-01 01:02:00    321.582963      46.084146   3.512600e-18
# 3  2018-01-01 01:03:00    321.582963      46.084146   0.000000e+00
# 4  2018-01-01 01:04:00    321.582963      46.084146   0.000000e+00
#
#    CDWL_PM_POW_3  CDWL_RW_TEMP  CDWL_SW_TEMP  CHL_CD_FLOW_1  CHL_CD_FLOW_2  \
# 0   0.000000e+00     69.188995     61.984875     321.582107       0.000429
# 1   0.000000e+00     68.880936     61.921814     321.582107       0.000429
# 2   1.600030e-34     68.577880     61.861610     321.582107       0.000429
# 3   0.000000e+00     68.299484     61.804260     321.582107       0.000429
# 4   0.000000e+00     68.241200     61.761360     321.582107       0.000429
#
#    CHL_CD_FLOW_3  ...  CWL_SEC_PM_POW_2  CWL_SEC_PM_SPD_1  CWL_SEC_PM_SPD_2  \
# 0       0.000429  ...          0.000000          1.000000          0.000000
# 1       0.000429  ...          0.000000          1.000000          0.000000
# 2       0.000429  ...          0.000000          1.000000          0.000000
# 3       0.000429  ...         44.184977          1.000000          1.000000
# 4       0.000429  ...         47.907713          0.976809          0.976809
#
#    CWL_SEC_PM_STA_1  CWL_SEC_PM_STA_2  CWL_SEC_RW_TEMP  CWL_SEC_SW_TEMP  \
# 0               1.0               0.0        56.816963        57.150177
# 1               1.0               0.0        56.630524        56.950665
# 2               1.0               0.0        56.450570        56.757965
# 3               1.0               1.0        61.190950        58.270123
# 4               1.0               1.0        61.764214        60.534187
#
#     OA_TEMP  OA_TEMP_WB  TWV_CTRL
# 0  9.070051   10.355011       0.0
# 1  8.771828   10.040033       0.0
# 2  8.786055   10.055031       0.0
# 3  8.800337   10.070026       0.0
# 4  8.814619   10.085022       0.0
#
# [5 rows x 78 columns]

# %%
data_normal.tail()
# Out:
#                    Datetime  CDWL_CW_FLOW  CDWL_PM_POW_1  CDWL_PM_POW_2  \
# 525535  2018-12-31 23:55:00    321.582963       7.643586   2.259722e-28
# 525536  2018-12-31 23:56:00    321.582963       7.643540   1.262641e-25
# 525537  2018-12-31 23:57:00    321.582963       7.643494   0.000000e+00
# 525538  2018-12-31 23:58:00    321.582963       7.643448   2.678305e-28
# 525539  2018-12-31 23:59:00    321.582963       7.643402   7.281571e-27
#
#         CDWL_PM_POW_3  CDWL_RW_TEMP  CDWL_SW_TEMP  CHL_CD_FLOW_1  \
# 525535   2.475577e-27     60.147797     59.998604     321.582107
# 525536   0.000000e+00     60.147743     59.998604     321.582107
# 525537   0.000000e+00     60.147686     59.998547     321.582107
# 525538   7.241329e-28     60.147686     59.998490     321.582107
# 525539   0.000000e+00     60.147630     59.998436     321.582107
#
#         CHL_CD_FLOW_2  CHL_CD_FLOW_3  ...  CWL_SEC_PM_POW_2  CWL_SEC_PM_SPD_1  \
# 525535       0.000429       0.000429  ...         27.807726          0.838999
# 525536       0.000429       0.000429  ...         27.807518          0.838998
# 525537       0.000429       0.000429  ...         27.807313          0.838996
# 525538       0.000429       0.000429  ...         27.807108          0.838995
# 525539       0.000429       0.000429  ...         27.806899          0.838993
#
#         CWL_SEC_PM_SPD_2  CWL_SEC_PM_STA_1  CWL_SEC_PM_STA_2  CWL_SEC_RW_TEMP  \
# 525535          0.838999               1.0               1.0        53.999626
# 525536          0.838998               1.0               1.0        53.999626
# 525537          0.838996               1.0               1.0        53.999626
# 525538          0.838995               1.0               1.0        53.999626
# 525539          0.838993               1.0               1.0        53.999626
#
#         CWL_SEC_SW_TEMP    OA_TEMP  OA_TEMP_WB  TWV_CTRL
# 525535        53.999626  19.845772   21.218018  0.510944
# 525536        53.999626  19.817920   21.185005  0.511098
# 525537        53.999626  19.790016   21.151989  0.511252
# 525538        53.999626  19.762110   21.119030  0.511406
# 525539        53.999626  19.734203   21.086018  0.511561
#
# [5 rows x 78 columns]

# %%
from datetime import datetime

# %%
print(f"Min Datetime: {min(data_normal.Datetime)}")
print(f"Max Datetime: {max(data_normal.Datetime)}")
print(f"Interval between measurements: {datetime.strptime(data_normal.Datetime[1], '%Y-%m-%d %H:%M:%S') - datetime.strptime(data_normal.Datetime[0], '%Y-%m-%d %H:%M:%S')}")
print(f"Number of measurements: {len(data_normal.index)}")
print(f"Number of features: {len(data_normal.columns) - 1}")
# Out:
# Min Datetime: 2018-01-01 01:00:00
# Max Datetime: 2018-12-31 23:59:00
# Interval between measurements: 0:01:00
# Number of measurements: 525540
# Number of features: 77

# %%
print("Features:")
print('\n'.join(sorted([el for el in data_normal.columns if el != 'Datetime'])))
# Out:
# Features:
# CDWL_CW_FLOW
# CDWL_PM_POW_1
# CDWL_PM_POW_2
# CDWL_PM_POW_3
# CDWL_RW_TEMP
# CDWL_SW_TEMP
# CHL_CD_FLOW_1
# CHL_CD_FLOW_2
# CHL_CD_FLOW_3
# CHL_COMP_SPD_CTRL_1
# CHL_COMP_SPD_CTRL_2
# CHL_COMP_SPD_CTRL_3
# CHL_CW_FLOW_1
# CHL_CW_FLOW_2
# CHL_CW_FLOW_3
# CHL_POW_1
# CHL_POW_2
# CHL_POW_3
# CHL_RWCD_TEMP_1
# CHL_RWCD_TEMP_2
# CHL_RWCD_TEMP_3
# CHL_RW_TEMP_1
# CHL_RW_TEMP_2
# CHL_RW_TEMP_3
# CHL_STA_1
# CHL_STA_2
# CHL_STA_3
# CHL_SWCD_TEMP_1
# CHL_SWCD_TEMP_2
# CHL_SWCD_TEMP_3
# CHL_SW_TEMP_1
# CHL_SW_TEMP_2
# CHL_SW_TEMP_3
# CT_FAN_SPD_1
# CT_FAN_SPD_2
# CT_FAN_SPD_3
# CT_FAN_SPD_CTRL_1
# CT_FAN_SPD_CTRL_2
# CT_FAN_SPD_CTRL_3
# CT_FLOW_1
# CT_FLOW_2
# CT_FLOW_3
# CT_POW_1
# CT_POW_2
# CT_POW_3
# CT_RW_TEMP_1
# CT_RW_TEMP_2
# CT_RW_TEMP_3
# CT_STA_1
# CT_STA_2
# CT_STA_3
# CT_SW_TEMPSPT
# CT_SW_TEMP_1
# CT_SW_TEMP_2
# CT_SW_TEMP_3
# CWL_PRI_CW_FLOW
# CWL_PRI_PM_POW_1
# CWL_PRI_PM_POW_2
# CWL_PRI_PM_POW_3
# CWL_PRI_RW_TEMP
# CWL_PRI_SW_TEMP
# CWL_PRI_SW_TEMPSPT
# CWL_SEC_CW_FLOW
# CWL_SEC_DP
# CWL_SEC_DPSPT
# CWL_SEC_LOAD
# CWL_SEC_PM_POW_1
# CWL_SEC_PM_POW_2
# CWL_SEC_PM_SPD_1
# CWL_SEC_PM_SPD_2
# CWL_SEC_PM_STA_1
# CWL_SEC_PM_STA_2
# CWL_SEC_RW_TEMP
# CWL_SEC_SW_TEMP
# OA_TEMP
# OA_TEMP_WB
# TWV_CTRL
