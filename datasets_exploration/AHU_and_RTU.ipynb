# %%
base_folder = r"C:\Users\tre_i\LBNL FDD Datasets"

# %%
dataset_folder = r"LBNL_FDD_Data_Sets_AHU_and_RTU\11752740"

# %%
from os.path import isfile, join
import os
import pandas as pd

# %%
folder = join(base_folder, dataset_folder)
os.listdir(folder)
# Out:
# ['LBNLDataSynthesisInventory.pdf',
#  'MZVAV-1.csv',
#  'MZVAV-2-1.csv',
#  'MZVAV-2-2.csv',
#  'RTU.csv',
#  'SZCAV.csv',
#  'SZVAV.csv']

# %%
data_SZCAV = pd.read_csv(join(folder, "SZCAV.csv"))
data_SZCAV
# Out:
#              Datetime  AHU: Supply Air Temperature  \
# 0      3/11/2017 0:00                        72.99
# 1      3/11/2017 0:01                        72.98
# 2      3/11/2017 0:02                        72.99
# 3      3/11/2017 0:03                        72.97
# 4      3/11/2017 0:04                        72.97
# ...               ...                          ...
# 21595  4/1/2017 23:55                        71.95
# 21596  4/1/2017 23:56                        71.95
# 21597  4/1/2017 23:57                        71.93
# 21598  4/1/2017 23:58                        71.93
# 21599  4/1/2017 23:59                        71.91
#
#        AHU: Supply Air Temperature Heating Set Point  \
# 0                                               50.0
# 1                                               50.0
# 2                                               50.0
# 3                                               50.0
# 4                                               50.0
# ...

# %%
data_SZVAV = pd.read_csv(join(folder, "SZVAV.csv"))
data_SZVAV
# Out:
#               Datetime  AHU: Supply Air Temperature  \
# 0       9/11/2017 0:00                        72.29
# 1       9/11/2017 0:01                        72.30
# 2       9/11/2017 0:02                        72.37
# 3       9/11/2017 0:03                        72.29
# 4       9/11/2017 0:04                        71.82
# ...                ...                          ...
# 15834  9/24/2017 23:54                        71.59
# 15835  9/24/2017 23:55                        71.58
# 15836  9/24/2017 23:56                        71.58
# 15837  9/24/2017 23:57                        71.57
# 15838  9/24/2017 23:58                        71.60
#
#        AHU: Supply Air Temperature Heating Set Point  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...

# %%
data_MZVAV_1 = pd.read_csv(join(folder, "MZVAV-1.csv"))
data_MZVAV_1
# Out:
#                 Datetime  AHU: Supply Air Temperature  \
# 0         1/30/2017 0:00                        68.00
# 1         1/30/2017 0:01                        67.99
# 2         1/30/2017 0:02                        67.99
# 3         1/30/2017 0:03                        67.99
# 4         1/30/2017 0:04                        67.99
# ...                  ...                          ...
# 272155  12/17/2017 23:55                        55.04
# 272156  12/17/2017 23:56                        55.04
# 272157  12/17/2017 23:57                        55.04
# 272158  12/17/2017 23:58                        55.04
# 272159  12/17/2017 23:59                        55.04
#
#         AHU: Supply Air Temperature Set Point  AHU: Outdoor Air Temperature  \
# 0                                       55.04                         32.00
# 1                                       55.04                         32.00
# 2                                       55.04                         -5.93
# ...

# %%
data_MZVAV_2_1 = pd.read_csv(join(folder, "MZVAV-2-1.csv"))
data_MZVAV_2_1
# Out:
#               Datetime  AHU: Supply Air Temperature  \
# 0       8/28/2007 0:00                        75.92
# 1       8/28/2007 0:01                        75.71
# 2       8/28/2007 0:02                        75.71
# 3       8/28/2007 0:03                        75.60
# 4       8/28/2007 0:04                        75.81
# ...                ...                          ...
# 21595  5/31/2009 23:55                        66.88
# 21596  5/31/2009 23:56                        66.77
# 21597  5/31/2009 23:57                        66.88
# 21598  5/31/2009 23:58                        66.99
# 21599  5/31/2009 23:59                        66.99
#
#        AHU: Supply Air Temperature Set Point  AHU: Outdoor Air Temperature  \
# 0                                         55                         80.61
# 1                                         55                         80.68
# 2                                         55                         80.66
# ...

# %%
data_MZVAV_2_2 = pd.read_csv(join(folder, "MZVAV-2-2.csv"))
data_MZVAV_2_2
# Out:
#               Datetime  AHU: Supply Air Temperature  \
# 0       8/28/2007 0:00                        77.13
# 1       8/28/2007 0:01                        77.63
# 2       8/28/2007 0:02                        77.87
# 3       8/28/2007 0:03                        77.95
# 4       8/28/2007 0:04                        78.59
# ...                ...                          ...
# 37435  5/15/2009 23:55                        62.56
# 37436  5/15/2009 23:56                        62.55
# 37437  5/15/2009 23:57                        62.54
# 37438  5/15/2009 23:58                        62.52
# 37439  5/15/2009 23:59                        62.51
#
#        AHU: Supply Air Temperature Set Point  AHU: Outdoor Air Temperature  \
# 0                                         55                         80.61
# 1                                         55                         80.68
# 2                                         55                         80.66
# ...

# %%
data_RTU = pd.read_csv(join(folder, "RTU.csv"))
data_RTU
# Out:
#              Timestamp  RTU: Supply Air Temperature  \
# 0       8/27/2017 0:00                          NaN
# 1       8/27/2017 0:01                          NaN
# 2       8/27/2017 0:02                          NaN
# 3       8/27/2017 0:03                          NaN
# 4       8/27/2017 0:04                          NaN
# ...                ...                          ...
# 30235  2/18/2018 23:55                          NaN
# 30236  2/18/2018 23:56                          NaN
# 30237  2/18/2018 23:57                          NaN
# 30238  2/18/2018 23:58                          NaN
# 30239  2/18/2018 23:59                          NaN
#
#        RTU: Return Air Temperature  RTU: Supply Air Fan Status  \
# 0                              NaN                           0
# 1                              NaN                           0
# 2                              NaN                           0
# 3                              NaN                           0
# ...

# %%
data_SZCAV.shape, data_SZVAV.shape, data_MZVAV_1.shape, data_MZVAV_2_1.shape, data_MZVAV_2_2.shape, data_MZVAV_2_2.shape, data_RTU.shape
# Out:
# ((21600, 16),
#  (15839, 16),
#  (272160, 18),
#  (21600, 19),
#  (37440, 19),
#  (37440, 19),
#  (30240, 69))
