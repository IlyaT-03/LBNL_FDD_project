# %%
base_folder = r"C:\Users\tre_i\LBNL FDD Datasets"

# %%
dataset_folder = 'LBNL_FDD_Data_Sets_SDAHU_all_3'

# %%
import os
from os.path import join
import pandas as pd

# %%
folder = join(base_folder, dataset_folder)
os.listdir(folder)
# Out:
# ['LBNL_FDD_Dataset_SDAHU',
#  'LBNL_FDD_Data_Sets_SDAHU.pdf',
#  'LBNL_FDD_Data_Sets_SDAHU_ttl.ttl']

# %%
data_folder = join(folder, 'LBNL_FDD_Dataset_SDAHU')
sorted(os.listdir(data_folder))
# Out:
# ['AHU_annual.csv',
#  'coi_bias_-2_annual.csv',
#  'coi_bias_-4_annual.csv',
#  'coi_bias_2_annual.csv',
#  'coi_bias_4_annual.csv',
#  'coi_leakage_010_annual.csv',
#  'coi_leakage_025_annual.csv',
#  'coi_leakage_040_annual.csv',
#  'coi_leakage_050_annual.csv',
#  'coi_stuck_010_annual.csv',
#  'coi_stuck_025_annual.csv',
#  'coi_stuck_050_annual.csv',
#  'coi_stuck_075_annual.csv',
#  'damper_stuck_010_annual.csv',
#  'damper_stuck_025_annual.csv',
#  'damper_stuck_075_annual.csv',
#  'damper_stuck_100_annual_short.csv',
#  'oa_bias_-2_annual.csv',
#  'oa_bias_-4_annual.csv',
#  'oa_bias_2_annual.csv',
#  'oa_bias_4_annual.csv']

# %%
len(sorted(os.listdir(data_folder)))
# Out:
# 21

# %%
data_normal = pd.read_csv(join(data_folder, 'AHU_annual.csv'))
data_normal.head()
# Out:
#               Datetime      CHWC_VLV  CHWC_VLV_DM    MA_TEMP     OA_CFM  \
# 0  2018-01-01 01:00:00  2.635303e-21          0.0  66.374680  357730.44
# 1  2018-01-01 01:01:00  2.479578e-21          0.0  66.374680  357730.44
# 2  2018-01-01 01:02:00  2.380361e-21          0.0  66.374680  357730.44
# 3  2018-01-01 01:03:00 -1.274259e-21          0.0  66.374626  357730.44
# 4  2018-01-01 01:04:00  2.749987e-21          0.0  66.374626  357730.44
#
#    OA_DMPR  OA_DMPR_DM    OA_TEMP    RA_CFM  RA_DMPR  ...  SF_CS  SF_SPD  \
# 0      0.0         0.0  10.355011  0.853194      1.0  ...    0.0     0.9
# 1      0.0         0.0  10.040033  0.853057      1.0  ...    0.0     0.9
# 2      0.0         0.0  10.055031  0.852918      1.0  ...    0.0     0.9
# 3      0.0         0.0  10.070026  0.852779      1.0  ...    0.0     0.9
# 4      0.0         0.0  10.085022  0.852641      1.0  ...    0.0     0.9
#
#    SF_SPD_DM        SF_WAT  SYS_CTL  ZONE_TEMP_1  ZONE_TEMP_2  ZONE_TEMP_3  \
# ...

# %%
from datetime import datetime

# %%
print(f"Min Datetime: {min(data_normal.Datetime)}")
print(f"Max Datetime: {max(data_normal.Datetime)}")
print(f"Interval between measurements: {datetime.strptime(data_normal.Datetime[1], '%Y-%m-%d %H:%M:%S') - datetime.strptime(data_normal.Datetime[0], '%Y-%m-%d %H:%M:%S')}")
print(f"Number of measurements: {len(data_normal.index)}")
print(f"Number of features: {len(data_normal.columns) - 1}")
# Out:
# Min Datetime: 2018-01-01 01:00:00
# Max Datetime: 2018-12-31 23:59:00
# Interval between measurements: 0:01:00
# Number of measurements: 525540
# Number of features: 30

# %%
print("Features:")
print('\n'.join(sorted([el for el in data_normal.columns if el != 'Datetime'])))
# Out:
# Features:
# CHWC_VLV
# CHWC_VLV_DM
# MA_TEMP
# OA_CFM
# OA_DMPR
# OA_DMPR_DM
# OA_TEMP
# RA_CFM
# RA_DMPR
# RA_DMPR_DM
# RA_TEMP
# RF_CS
# RF_SPD
# RF_SPD_DM
# RF_WAT
# SA_CFM
# SA_SP
# SA_SPSPT
# SA_TEMP
# SA_TEMPSPT
# SF_CS
# SF_SPD
# SF_SPD_DM
# SF_WAT
# SYS_CTL
# ZONE_TEMP_1
# ZONE_TEMP_2
# ZONE_TEMP_3
# ZONE_TEMP_4
# ZONE_TEMP_5

# %%
description_file = join(folder, 'LBNL_FDD_Data_Sets_SDAHU.pdf')

# %%
# !pip install tabula-py
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install camelot-py[cv]
# !pip install ghostscript
# Out:
# ...
#    ---------------------------------------- 0.0/38.9 MB ? eta -:--:--
#    - -------------------------------------- 1.8/38.9 MB 8.4 MB/s eta 0:00:05
#    --- ------------------------------------ 3.7/38.9 MB 8.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.5/38.9 MB 9.3 MB/s eta 0:00:04
#    ------- -------------------------------- 7.3/38.9 MB 9.1 MB/s eta 0:00:04
#    --------- ------------------------------ 8.9/38.9 MB 8.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.0/38.9 MB 9.0 MB/s eta 0:00:04
#    -------------- ------------------------- 13.6/38.9 MB 9.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.7/38.9 MB 9.4 MB/s eta 0:00:03
#    ------------------ --------------------- 17.8/38.9 MB 9.5 MB/s eta 0:00:03
#    -------------------- ------------------- 20.2/38.9 MB 9.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.8/38.9 MB 9.9 MB/s eta 0:00:02
# ...

# %%
import camelot

# Попробуем оба режима, stream и lattice
tables_stream = camelot.read_pdf(description_file, pages="1-end", flavor="stream")
tables_lattice = camelot.read_pdf(description_file, pages="1-end", flavor="lattice")

print("Stream tables:", tables_stream.n)
print("Lattice tables:", tables_lattice.n)
# Out:
# C:\Users\tre_i\PycharmProjects\ScienceRAG\.venv\Lib\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4
# C:\Users\tre_i\PycharmProjects\ScienceRAG\.venv\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (0, 0, 612.0, 792.0)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# C:\Users\tre_i\PycharmProjects\ScienceRAG\.venv\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (62.024, 549.0600000000001, 550.7272, 772.7699999999998)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# ...

# %%
table2 = camelot.read_pdf(description_file, pages="5-7", flavor="stream")
table2[0].df.head()
# Out:
# C:\Users\tre_i\PycharmProjects\ScienceRAG\.venv\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (98.02, 67.544, 549.1872000000001, 360.02161739130423)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# C:\Users\tre_i\PycharmProjects\ScienceRAG\.venv\Lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (62.024, 526.86, 550.5107999999999, 769.5775226373627)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
#                                                    0
# 0  Control sequences for the single-duct AHU for ...
# 1  ccupied mode (Monday – Friday 6:00am – 10:00pm...
# 2  ●  Fan status: The supply fan and return fan r...
# 3  ●  Supply air temperature control: The supply ...
# 4  valve to maintain a fixed setpoint of 55°F whe...
