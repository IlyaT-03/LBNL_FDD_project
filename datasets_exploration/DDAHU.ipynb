# %%
base_folder = r"C:\Users\tre_i\LBNL FDD Datasets"

# %%
dataset_folder = 'LBNL_FDD_Data_Sets_DDAHU_all_3'

# %%
import os
from os.path import join
import pandas as pd

# %%
folder = join(base_folder, dataset_folder)
os.listdir(folder)
# Out:
# ['LBNL FDD Data Sets_DDAHU.pdf',
#  'LBNL_FDD_Data_Sets_DDAHU',
#  'LBNL_FDD_Data_Sets_DDAHU_ttl.ttl']

# %%
data_folder = join(folder, 'LBNL_FDD_Data_Sets_DDAHU')
sorted(os.listdir(data_folder))
# Out:
# ['DualDuct_CoolSeqUnstable.csv',
#  'DualDuct_DMPRStuck_Cold_0.csv',
#  'DualDuct_DMPRStuck_Cold_100.csv',
#  'DualDuct_DMPRStuck_Cold_20.csv',
#  'DualDuct_DMPRStuck_Cold_50.csv',
#  'DualDuct_DMPRStuck_Cold_80.csv',
#  'DualDuct_DMPRStuck_Hot_0.csv',
#  'DualDuct_DMPRStuck_Hot_100.csv',
#  'DualDuct_DMPRStuck_Hot_20.csv',
#  'DualDuct_DMPRStuck_Hot_50.csv',
#  'DualDuct_DMPRStuck_Hot_80.csv',
#  'DualDuct_DMPRStuck_OA_0.csv',
#  'DualDuct_DMPRStuck_OA_100.csv',
#  'DualDuct_DMPRStuck_OA_28.csv',
#  'DualDuct_DMPRStuck_OA_45.csv',
#  'DualDuct_DMPRStuck_OA_80.csv',
#  'DualDuct_FaultFree.csv',
#  'DualDuct_Fouling_Cooling_Airside_Minor.csv',
#  'DualDuct_Fouling_Cooling_Airside_Moderate.csv',
#  'DualDuct_Fouling_Cooling_Airside_Severe.csv',
#  'DualDuct_Fouling_Cooling_Waterside_Minor.csv',
#  'DualDuct_Fouling_Cooling_Waterside_Moderate.csv',
#  'DualDuct_Fouling_Cooling_Waterside_Severe.csv',
#  'DualDuct_Fouling_Heating_Airside_Minor.csv',
#  'DualDuct_Fouling_Heating_Airside_Moderate.csv',
#  'DualDuct_Fouling_Heating_Airside_Severe.csv',
#  'DualDuct_Fouling_Heating_Waterside_Minor.csv',
#  'DualDuct_Fouling_Heating_Waterside_Moderate.csv',
#  'DualDuct_Fouling_Heating_Waterside_Severe.csv',
#  'DualDuct_HeatSeqUnstable.csv',
#  'DualDuct_SensorBias_CSA_+2C.csv',
#  'DualDuct_SensorBias_CSA_+4C.csv',
#  'DualDuct_SensorBias_CSA_-2C.csv',
#  'DualDuct_SensorBias_CSA_-4C.csv',
#  'DualDuct_SensorBias_CSP_+2inwg.csv',
#  'DualDuct_SensorBias_CSP_+4inwg.csv',
#  'DualDuct_SensorBias_CSP_-2inwg.csv',
#  'DualDuct_SensorBias_CSP_-4inwg.csv',
#  'DualDuct_SensorBias_HSA_+2C.csv',
#  'DualDuct_SensorBias_HSA_+4C.csv',
#  'DualDuct_SensorBias_HSA_-2C.csv',
#  'DualDuct_SensorBias_HSA_-4C.csv',
#  'DualDuct_SensorBias_HSP_+2inwg.csv',
#  'DualDuct_SensorBias_HSP_+4inwg.csv',
#  'DualDuct_SensorBias_HSP_-2inwg.csv',
#  'DualDuct_SensorBias_HSP_-4inwg.csv',
#  'DualDuct_VLVStuck_Cooling_0_.csv',
#  'DualDuct_VLVStuck_Cooling_100_.csv',
#  'DualDuct_VLVStuck_Cooling_20_.csv',
#  'DualDuct_VLVStuck_Cooling_50_.csv',
#  'DualDuct_VLVStuck_Cooling_80_.csv',
#  'DualDuct_VLVStuck_Heating_0_.csv',
#  'DualDuct_VLVStuck_Heating_100_.csv',
#  'DualDuct_VLVStuck_Heating_20_.csv',
#  'DualDuct_VLVStuck_Heating_50_.csv',
#  'DualDuct_VLVStuck_Heating_80_.csv']

# %%
len(sorted(os.listdir(data_folder)))
# Out:
# 56

# %%
data_normal = pd.read_csv(join(data_folder, 'DualDuct_FaultFree.csv'))
data_normal.head()
# Out:
#            Datetime  RM_TEMP_W  RMCLGSPT_W  RMHTGSPT_W  VAV_DAT_W  VAV_SP_C_W  \
# 0  01/01/2018 00:00      66.95        85.0        55.0      68.02         0.0
# 1  01/01/2018 00:01      66.95        85.0        55.0      68.02         0.0
# 2  01/01/2018 00:02      66.95        85.0        55.0      68.02         0.0
# 3  01/01/2018 00:03      66.95        85.0        55.0      68.02         0.0
# 4  01/01/2018 00:04      66.95        85.0        55.0      68.02         0.0
#
#    VAV_SP_H_W  VAV_DMPR_C_W  VAV_DMPR_H_W  VAVCFM_C_DM_W  ...  HWP_GPMT  \
# 0         0.0          0.28          0.42            0.0  ...      7.84
# 1         0.0          0.28          0.42            0.0  ...      7.84
# 2         0.0          0.28          0.42            0.0  ...      7.84
# 3         0.0          0.28          0.42            0.0  ...      7.84
# 4         0.0          0.28          0.42            0.0  ...      7.84
#
#    CHWC_DAT  CHWC_EAH  CHWC_EWT  CHWC_LWT  CHWC_MWT  CHWC_VLV  CHWC_VLV_DM  \
# 0     50.33     45.09      45.0     50.33      45.0       0.0          0.0
# 1     50.33     45.09      45.0     50.33      45.0       0.0          0.0
# 2     50.33     45.02      45.0     50.33      45.0       0.0          0.0
# 3     50.33     45.02      45.0     50.33      45.0       0.0          0.0
# 4     50.33     45.02      45.0     50.33      45.0       0.0          0.0
#
#    CHWP_GPMC  CHWP_GPMT
# 0        0.0      27.57
# 1        0.0      27.57
# 2        0.0      27.57
# 3        0.0      27.57
# 4        0.0      27.57
#
# [5 rows x 115 columns]

# %%
data_normal.tail()
# Out:
#                 Datetime  RM_TEMP_W  RMCLGSPT_W  RMHTGSPT_W  VAV_DAT_W  \
# 525595  12/31/2018 23:55      61.00        85.0        55.0      68.11
# 525596  12/31/2018 23:56      60.99        85.0        55.0      68.11
# 525597  12/31/2018 23:57      60.98        85.0        55.0      68.11
# 525598  12/31/2018 23:58      60.98        85.0        55.0      68.11
# 525599  12/31/2018 23:59      60.97        85.0        55.0      68.11
#
#         VAV_SP_C_W  VAV_SP_H_W  VAV_DMPR_C_W  VAV_DMPR_H_W  VAVCFM_C_DM_W  \
# 525595         0.0         0.0          0.28          0.42            0.0
# 525596         0.0         0.0          0.28          0.42            0.0
# 525597         0.0         0.0          0.28          0.42            0.0
# 525598         0.0         0.0          0.28          0.42            0.0
# 525599         0.0         0.0          0.28          0.42            0.0
#
#         ...  HWP_GPMT  CHWC_DAT  CHWC_EAH  CHWC_EWT  CHWC_LWT  CHWC_MWT  \
# 525595  ...      7.84     50.51     100.0      45.0     50.51      45.0
# 525596  ...      7.84     50.51     100.0      45.0     50.51      45.0
# 525597  ...      7.84     50.51     100.0      45.0     50.51      45.0
# 525598  ...      7.84     50.51     100.0      45.0     50.51      45.0
# 525599  ...      7.84     50.51     100.0      45.0     50.51      45.0
#
#         CHWC_VLV  CHWC_VLV_DM  CHWP_GPMC  CHWP_GPMT
# 525595       0.0          0.0        0.0      27.57
# 525596       0.0          0.0        0.0      27.57
# 525597       0.0          0.0        0.0      27.57
# 525598       0.0          0.0        0.0      27.57
# 525599       0.0          0.0        0.0      27.57
#
# [5 rows x 115 columns]

# %%
from datetime import datetime

# %%
print(f"Min Datetime: {min(data_normal.Datetime)}")
print(f"Max Datetime: {max(data_normal.Datetime)}")
print(f"Interval between measurements: {datetime.strptime(data_normal.Datetime[1], '%m/%d/%Y %H:%M') - datetime.strptime(data_normal.Datetime[0], '%m/%d/%Y %H:%M')}")
print(f"Number of measurements: {len(data_normal.index)}")
print(f"Number of features: {len(data_normal.columns) - 1}")
# Out:
# Min Datetime: 01/01/2018 00:00
# Max Datetime: 12/31/2018 23:59
# Interval between measurements: 0:01:00
# Number of measurements: 525600
# Number of features: 114

# %%
print("Features:")
print('\n'.join(sorted([el for el in data_normal.columns if el != 'Datetime'])))
# Out:
# Features:
# CHWC_DAT
# CHWC_EAH
# CHWC_EWT
# CHWC_LWT
# CHWC_MWT
# CHWC_VLV
# CHWC_VLV_DM
# CHWP_GPMC
# CHWP_GPMT
# CSA_CFM
# CSA_HUMD
# CSA_SP
# CSA_SPSPT
# CSA_TEMP
# CSA_TEMPSPT
# CSF_CS
# CSF_DP
# CSF_SPD
# CSF_WAT
# EA_DMPR
# EA_DMPR_DM
# HSA_CFM
# HSA_HUMD
# HSA_SP
# HSA_SPSPT
# HSA_TEMP
# HSA_TEMPSPT
# HSF_CS
# HSF_DP
# HSF_SPD
# HSF_WAT
# HWC_DAT
# HWC_EWT
# HWC_LWT
# HWC_MWT
# HWC_VLV
# HWC_VLV_DM
# HWP_GPMC
# HWP_GPMT
# MA_TEMP
# OA_CFM
# OA_DMPR
# OA_DMPR_DM
# OA_HUMD
# OA_TEMP
# RA_CFM
# RA_DMPR
# RA_DMPR_DM
# RA_HUMD
# RA_TEMP
# RF_DP
# RF_SPD
# RF_WAT
# RMCLGSPT_E
# RMCLGSPT_SA
# RMCLGSPT_SB
# RMCLGSPT_W
# RMHTGSPT_E
# RMHTGSPT_SA
# RMHTGSPT_SB
# RMHTGSPT_W
# RM_TEMP_E
# RM_TEMP_SA
# RM_TEMP_SB
# RM_TEMP_W
# SYS_CTL
# VAVCFM_C_DM_E
# VAVCFM_C_DM_SA
# VAVCFM_C_DM_SB
# VAVCFM_C_DM_W
# VAVCFM_C_E
# VAVCFM_C_SA
# VAVCFM_C_SB
# VAVCFM_C_W
# VAVCFM_H_DM_E
# VAVCFM_H_DM_SA
# VAVCFM_H_DM_SB
# VAVCFM_H_DM_W
# VAVCFM_H_E
# VAVCFM_H_SA
# VAVCFM_H_SB
# VAVCFM_H_W
# VAVCFM_T_E
# VAVCFM_T_SA
# VAVCFM_T_SB
# VAVCFM_T_W
# VAV_DAT_E
# VAV_DAT_SA
# VAV_DAT_SB
# VAV_DAT_W
# VAV_DMPR_C_E
# VAV_DMPR_C_SA
# VAV_DMPR_C_SB
# VAV_DMPR_C_W
# VAV_DMPR_H_E
# VAV_DMPR_H_SA
# VAV_DMPR_H_SB
# VAV_DMPR_H_W
# VAV_EAT_C_E
# VAV_EAT_C_SA
# VAV_EAT_C_SB
# VAV_EAT_C_W
# VAV_EAT_H_E
# VAV_EAT_H_SA
# VAV_EAT_H_SB
# VAV_EAT_H_W
# VAV_SP_C_E
# VAV_SP_C_SA
# VAV_SP_C_SB
# VAV_SP_C_W
# VAV_SP_H_E
# VAV_SP_H_SA
# VAV_SP_H_SB
# VAV_SP_H_W
